# %%
###Binomial distribution is use where there are only two outcomes 


# success and failure 


#consider the success is p then failure is (1-p) .


# * important  note :
    
#     mean     =np 
#     variance =npq 
#     standard deviation is =(npq)**1/2

# %%
import numpy as np 

from scipy.stats import binom

# %%
n=90
p=0.5
r_values=[i for i in range(n+1)]

pr=probability_mass_function=[binom.pmf(r,n,p) for r in r_values]

print(len(r_values))



for i in range(len(r_values)):

   print(f"the binomial distribution for {i} success is {pr[i]}")
# Out:
# 91
# the binomial distribution for 0 success is 8.077935669463161e-28
# the binomial distribution for 1 success is 7.270142102516941e-26
# the binomial distribution for 2 success is 3.2352132356199618e-24
# the binomial distribution for 3 success is 9.489958824485259e-23
# the binomial distribution for 4 success is 2.064066044325565e-21
# the binomial distribution for 5 success is 3.5501935962399455e-20
# the binomial distribution for 6 success is 5.029440928006607e-19
# the binomial distribution for 7 success is 6.035329113607954e-18
# the binomial distribution for 8 success is 6.261653955368238e-17
# the binomial distribution for 9 success is 5.7050624926688115e-16
# the binomial distribution for 10 success is 4.6211006190617785e-15
# the binomial distribution for 11 success is 3.360800450226713e-14
# the binomial distribution for 12 success is 2.2125269630659112e-13
# the binomial distribution for 13 success is 1.327516177839548e-12
# ...

# %%
def
